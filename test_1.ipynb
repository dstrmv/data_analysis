# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "data/final_test/exam1.csv"

df = pd.read_csv(csv_path, sep=';')


plt.plot(df.X, df.Y)
plt.plot(df.X, df.Z)
plt.plot(df.X, df.L)
plt.plot(df.X, df.R)
