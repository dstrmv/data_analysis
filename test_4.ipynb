# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

s = pd.Series([35, 34, 41, 37, 36, 44, 56, 54, 55, 51, 46, 45, 47, 63, 62, 50, 53, 61, 64, 67, 69, 66, 72, 65, 74])
x = s.index
y = s.values

x_c = sm.add_constant(x)
model = sm.OLS(y, x_c).fit()
predictions = model.predict(x_c)

print_model = model.summary()

print_model
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     95.46
# Date:                Sun, 04 Oct 2020   Prob (F-statistic):           1.18e-09
# Time:                        23:55:56   Log-Likelihood:                -76.914
# No. Observations:                  25   AIC:                             157.8
# Df Residuals:                      23   BIC:                             160.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.0923      2.124     16.992      0.000      31.698      40.486
# x1             1.4823      0.152      9.770      0.000       1.168       1.796
# ==============================================================================
# Omnibus:                        1.276   Durbin-Watson:                   1.357
# Prob(Omnibus):                  0.528   Jarque-Bera (JB):                0.947
# Skew:                           0.172   Prob(JB):                        0.623
# Kurtosis:                       2.111   Cond. No.                         27.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.plot(x, predictions)
plt.plot(x, y)
