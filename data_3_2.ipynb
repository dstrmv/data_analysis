# %%
import pandas as pd
import numpy as np

s = pd.Series([45, 48, 43, 44, 55, 42, 40, 49, 50, 56, 54, 61, 60, 64, 53, 59, 47, 57, 51, 68])

s.plot()

# %%
al = s.ewm(alpha=0.12)
val = al.mean()[19]
floored = np.floor(val)
floored
# Out:
# 55.0
